# %%
import tweepy
import csv
#import pandas as pd
#import datetime
from twitter_keys import consumer_key, consumer_secret, access_token, access_secret
#import pickle
import matplotlib.pyplot as plt; plt.rcdefaults()
import numpy as np
import matplotlib.pyplot as plt


auth = tweepy.OAuthHandler(consumer_key,consumer_secret)
auth.set_access_token(access_token,access_secret)

api = tweepy.API(auth)

# %%
csvFile = open('azure.csv', 'w')

csvWriter = csv.writer(csvFile)

for tweet in tweepy.Cursor(api.search,q="#Azure",
                           lang="en").items(100):
    #print (tweet.text)
    csvWriter.writerow([tweet.text.encode('utf-8')])
    

    
from nltk_helper import get_sentiments
    


for tweet in tweepy.Cursor(api.search,q="#Azure",
                           lang="en").items(100):
    print("Azure tweets : ",get_sentiments(tweet.text))
print()


Azure=tweepy.Cursor(api.search,q="#Azure",
                           lang="en").items(100)


# salesforce

csvFile = open('salesforce.csv', 'w')

csvWriter = csv.writer(csvFile)


for tweet in tweepy.Cursor(api.search,q="#salesforce",
                           lang="en").items(100):
    #print (tweet.text)
    csvWriter.writerow([tweet.text.encode('utf-8')])
    

    
from nltk_helper import get_sentiments
    


for tweet in tweepy.Cursor(api.search,q="#salesforce",
                           lang="en").items(100):
    print("salesforce tweets : ",get_sentiments(tweet.text))
print()


salesforce=tweepy.Cursor(api.search,q="#salesforce",
                           lang="en").items(100)


#AWS

csvFile = open('AWS.csv', 'w')

csvWriter = csv.writer(csvFile)

for tweet in tweepy.Cursor(api.search,q="#AWS",
                           lang="en").items(100):
    #print (tweet.text)
    csvWriter.writerow([tweet.text.encode('utf-8')])
    

    
from nltk_helper import get_sentiments
    

for tweet in tweepy.Cursor(api.search,q="#AWS",lang="en").items(100):
                           
                           print("AWS tweets : ",get_sentiments(tweet.text))
    
print()


AWS=tweepy.Cursor(api.search,q="#AWS",
                           lang="en").items(100)
# Out:
# [nltk_data] Downloading package vader_lexicon to
# [nltk_data]     C:\Users\s534846\AppData\Roaming\nltk_data...
# [nltk_data]   Package vader_lexicon is already up-to-date!
# Azure tweets :  {'neg': 0.129, 'neu': 0.792, 'pos': 0.079, 'compound': -0.296}
# Azure tweets :  {'neg': 0.0, 'neu': 0.882, 'pos': 0.118, 'compound': 0.25}
# Azure tweets :  {'neg': 0.0, 'neu': 1.0, 'pos': 0.0, 'compound': 0.0}
# Azure tweets :  {'neg': 0.0, 'neu': 0.701, 'pos': 0.299, 'compound': 0.75}
# Azure tweets :  {'neg': 0.0, 'neu': 0.674, 'pos': 0.326, 'compound': 0.8481}
# Azure tweets :  {'neg': 0.0, 'neu': 0.778, 'pos': 0.222, 'compound': 0.6908}
# Azure tweets :  {'neg': 0.0, 'neu': 0.846, 'pos': 0.154, 'compound': 0.4767}
# Azure tweets :  {'neg': 0.0, 'neu': 1.0, 'pos': 0.0, 'compound': 0.0}
# Azure tweets :  {'neg': 0.0, 'neu': 0.829, 'pos': 0.171, 'compound': 0.4767}
# Azure tweets :  {'neg': 0.0, 'neu': 0.848, 'pos': 0.152, 'compound': 0.34}
# Azure tweets :  {'neg': 0.0, 'neu': 0.848, 'pos': 0.152, 'compound': 0.34}
# Azure tweets :  {'neg': 0.0, 'neu': 0.939, 'pos': 0.061, 'compound': 0.0258}
# Azure tweets :  {'neg': 0.0, 'neu': 1.0, 'pos': 0.0, 'compound': 0.0}
# Azure tweets :  {'neg': 0.0, 'neu': 1.0, 'pos': 0.0, 'compound': 0.0}
# Azure tweets :  {'neg': 0.0, 'neu': 1.0, 'pos': 0.0, 'compound': 0.0}
# Azure tweets :  {'neg': 0.0, 'neu': 1.0, 'pos': 0.0, 'compound': 0.0}
# Azure tweets :  {'neg': 0.0, 'neu': 1.0, 'pos': 0.0, 'compound': 0.0}
# Azure tweets :  {'neg': 0.0, 'neu': 1.0, 'pos': 0.0, 'compound': 0.0}
# Azure tweets :  {'neg': 0.0, 'neu': 1.0, 'pos': 0.0, 'compound': 0.0}
# Azure tweets :  {'neg': 0.0, 'neu': 1.0, 'pos': 0.0, 'compound': 0.0}
# Azure tweets :  {'neg': 0.0, 'neu': 1.0, 'pos': 0.0, 'compound': 0.0}
# Azure tweets :  {'neg': 0.0, 'neu': 1.0, 'pos': 0.0, 'compound': 0.0}
# Azure tweets :  {'neg': 0.0, 'neu': 0.881, 'pos': 0.119, 'compound': 0.3182}
# Azure tweets :  {'neg': 0.0, 'neu': 0.732, 'pos': 0.268, 'compound': 0.765}
# Azure tweets :  {'neg': 0.0, 'neu': 0.881, 'pos': 0.119, 'compound': 0.3182}
# Azure tweets :  {'neg': 0.0, 'neu': 0.881, 'pos': 0.119, 'compound': 0.3182}
# Azure tweets :  {'neg': 0.0, 'neu': 0.881, 'pos': 0.119, 'compound': 0.3182}
# Azure tweets :  {'neg': 0.0, 'neu': 0.881, 'pos': 0.119, 'compound': 0.3182}
# Azure tweets :  {'neg': 0.0, 'neu': 1.0, 'pos': 0.0, 'compound': 0.0}
# Azure tweets :  {'neg': 0.0, 'neu': 1.0, 'pos': 0.0, 'compound': 0.0}
# Azure tweets :  {'neg': 0.0, 'neu': 0.881, 'pos': 0.119, 'compound': 0.3182}
# Azure tweets :  {'neg': 0.0, 'neu': 0.881, 'pos': 0.119, 'compound': 0.3182}
# Azure tweets :  {'neg': 0.0, 'neu': 0.881, 'pos': 0.119, 'compound': 0.3182}
# Azure tweets :  {'neg': 0.0, 'neu': 0.881, 'pos': 0.119, 'compound': 0.3182}
# Azure tweets :  {'neg': 0.0, 'neu': 0.881, 'pos': 0.119, 'compound': 0.3182}
# Azure tweets :  {'neg': 0.0, 'neu': 0.859, 'pos': 0.141, 'compound': 0.3182}
# Azure tweets :  {'neg': 0.0, 'neu': 0.563, 'pos': 0.437, 'compound': 0.9215}
# Azure tweets :  {'neg': 0.0, 'neu': 1.0, 'pos': 0.0, 'compound': 0.0}
# Azure tweets :  {'neg': 0.0, 'neu': 1.0, 'pos': 0.0, 'compound': 0.0}
# Azure tweets :  {'neg': 0.0, 'neu': 0.897, 'pos': 0.103, 'compound': 0.3182}
# Azure tweets :  {'neg': 0.0, 'neu': 0.775, 'pos': 0.225, 'compound': 0.4404}
# Azure tweets :  {'neg': 0.0, 'neu': 1.0, 'pos': 0.0, 'compound': 0.0}
# Azure tweets :  {'neg': 0.192, 'neu': 0.808, 'pos': 0.0, 'compound': -0.508}
# Azure tweets :  {'neg': 0.0, 'neu': 1.0, 'pos': 0.0, 'compound': 0.0}
# Azure tweets :  {'neg': 0.0, 'neu': 1.0, 'pos': 0.0, 'compound': 0.0}
# Azure tweets :  {'neg': 0.0, 'neu': 0.833, 'pos': 0.167, 'compound': 0.3818}
# Azure tweets :  {'neg': 0.0, 'neu': 0.819, 'pos': 0.181, 'compound': 0.4915}
# Azure tweets :  {'neg': 0.0, 'neu': 1.0, 'pos': 0.0, 'compound': 0.0}
# Azure tweets :  {'neg': 0.0, 'neu': 1.0, 'pos': 0.0, 'compound': 0.0}
# Azure tweets :  {'neg': 0.099, 'neu': 0.807, 'pos': 0.094, 'compound': -0.0258}
# Azure tweets :  {'neg': 0.0, 'neu': 0.922, 'pos': 0.078, 'compound': 0.1779}
# Azure tweets :  {'neg': 0.0, 'neu': 1.0, 'pos': 0.0, 'compound': 0.0}
# Azure tweets :  {'neg': 0.0, 'neu': 0.645, 'pos': 0.355, 'compound': 0.765}
# Azure tweets :  {'neg': 0.0, 'neu': 0.704, 'pos': 0.296, 'compound': 0.6369}
# Azure tweets :  {'neg': 0.0, 'neu': 0.491, 'pos': 0.509, 'compound': 0.9485}
# Azure tweets :  {'neg': 0.0, 'neu': 1.0, 'pos': 0.0, 'compound': 0.0}
# Azure tweets :  {'neg': 0.0, 'neu': 1.0, 'pos': 0.0, 'compound': 0.0}
# Azure tweets :  {'neg': 0.0, 'neu': 1.0, 'pos': 0.0, 'compound': 0.0}
# Azure tweets :  {'neg': 0.0, 'neu': 0.739, 'pos': 0.261, 'compound': 0.8309}
# Azure tweets :  {'neg': 0.0, 'neu': 0.72, 'pos': 0.28, 'compound': 0.8309}
# Azure tweets :  {'neg': 0.0, 'neu': 0.889, 'pos': 0.111, 'compound': 0.3612}
# Azure tweets :  {'neg': 0.0, 'neu': 0.61, 'pos': 0.39, 'compound': 0.8625}
# Azure tweets :  {'neg': 0.0, 'neu': 1.0, 'pos': 0.0, 'compound': 0.0}
# Azure tweets :  {'neg': 0.074, 'neu': 0.837, 'pos': 0.088, 'compound': 0.0772}
# Azure tweets :  {'neg': 0.0, 'neu': 0.763, 'pos': 0.237, 'compound': 0.68}
# Azure tweets :  {'neg': 0.0, 'neu': 0.82, 'pos': 0.18, 'compound': 0.296}
# Azure tweets :  {'neg': 0.0, 'neu': 1.0, 'pos': 0.0, 'compound': 0.0}
# Azure tweets :  {'neg': 0.0, 'neu': 0.597, 'pos': 0.403, 'compound': 0.9033}
# Azure tweets :  {'neg': 0.0, 'neu': 0.732, 'pos': 0.268, 'compound': 0.296}
# Azure tweets :  {'neg': 0.0, 'neu': 0.884, 'pos': 0.116, 'compound': 0.2732}
# Azure tweets :  {'neg': 0.0, 'neu': 1.0, 'pos': 0.0, 'compound': 0.0}
# Azure tweets :  {'neg': 0.0, 'neu': 0.847, 'pos': 0.153, 'compound': 0.4019}
# Azure tweets :  {'neg': 0.0, 'neu': 1.0, 'pos': 0.0, 'compound': 0.0}
# Azure tweets :  {'neg': 0.0, 'neu': 1.0, 'pos': 0.0, 'compound': 0.0}
# Azure tweets :  {'neg': 0.0, 'neu': 1.0, 'pos': 0.0, 'compound': 0.0}
# Azure tweets :  {'neg': 0.179, 'neu': 0.708, 'pos': 0.113, 'compound': -0.3382}
# Azure tweets :  {'neg': 0.0, 'neu': 1.0, 'pos': 0.0, 'compound': 0.0}
# Azure tweets :  {'neg': 0.098, 'neu': 0.793, 'pos': 0.11, 'compound': 0.0516}
# Azure tweets :  {'neg': 0.0, 'neu': 1.0, 'pos': 0.0, 'compound': 0.0}
# Azure tweets :  {'neg': 0.0, 'neu': 0.878, 'pos': 0.122, 'compound': 0.3612}
# Azure tweets :  {'neg': 0.0, 'neu': 0.748, 'pos': 0.252, 'compound': 0.4019}
# Azure tweets :  {'neg': 0.0, 'neu': 1.0, 'pos': 0.0, 'compound': 0.0}
# Azure tweets :  {'neg': 0.0, 'neu': 0.863, 'pos': 0.137, 'compound': 0.4019}
# Azure tweets :  {'neg': 0.0, 'neu': 1.0, 'pos': 0.0, 'compound': 0.0}
# Azure tweets :  {'neg': 0.0, 'neu': 1.0, 'pos': 0.0, 'compound': 0.0}
# Azure tweets :  {'neg': 0.0, 'neu': 1.0, 'pos': 0.0, 'compound': 0.0}
# Azure tweets :  {'neg': 0.0, 'neu': 1.0, 'pos': 0.0, 'compound': 0.0}
# Azure tweets :  {'neg': 0.0, 'neu': 0.856, 'pos': 0.144, 'compound': 0.4019}
# Azure tweets :  {'neg': 0.0, 'neu': 1.0, 'pos': 0.0, 'compound': 0.0}
# Azure tweets :  {'neg': 0.0, 'neu': 1.0, 'pos': 0.0, 'compound': 0.0}
# Azure tweets :  {'neg': 0.0, 'neu': 0.894, 'pos': 0.106, 'compound': 0.2263}
# Azure tweets :  {'neg': 0.0, 'neu': 0.863, 'pos': 0.137, 'compound': 0.4005}
# Azure tweets :  {'neg': 0.0, 'neu': 0.833, 'pos': 0.167, 'compound': 0.3818}
# Azure tweets :  {'neg': 0.0, 'neu': 0.787, 'pos': 0.213, 'compound': 0.4019}
# Azure tweets :  {'neg': 0.0, 'neu': 1.0, 'pos': 0.0, 'compound': 0.0}
# Azure tweets :  {'neg': 0.0, 'neu': 0.838, 'pos': 0.162, 'compound': 0.4019}
# Azure tweets :  {'neg': 0.0, 'neu': 0.838, 'pos': 0.162, 'compound': 0.4019}
# Azure tweets :  {'neg': 0.0, 'neu': 1.0, 'pos': 0.0, 'compound': 0.0}
# Azure tweets :  {'neg': 0.0, 'neu': 0.739, 'pos': 0.261, 'compound': 0.6486}
# Azure tweets :  {'neg': 0.0, 'neu': 1.0, 'pos': 0.0, 'compound': 0.0}
#
# salesforce tweets :  {'neg': 0.0, 'neu': 0.872, 'pos': 0.128, 'compound': 0.3612}
# salesforce tweets :  {'neg': 0.0, 'neu': 1.0, 'pos': 0.0, 'compound': 0.0}
# salesforce tweets :  {'neg': 0.0, 'neu': 0.605, 'pos': 0.395, 'compound': 0.7579}
# salesforce tweets :  {'neg': 0.0, 'neu': 1.0, 'pos': 0.0, 'compound': 0.0}
# salesforce tweets :  {'neg': 0.0, 'neu': 1.0, 'pos': 0.0, 'compound': 0.0}
# salesforce tweets :  {'neg': 0.0, 'neu': 1.0, 'pos': 0.0, 'compound': 0.0}
# salesforce tweets :  {'neg': 0.0, 'neu': 1.0, 'pos': 0.0, 'compound': 0.0}
# salesforce tweets :  {'neg': 0.0, 'neu': 0.906, 'pos': 0.094, 'compound': 0.34}
# salesforce tweets :  {'neg': 0.0, 'neu': 1.0, 'pos': 0.0, 'compound': 0.0}
# salesforce tweets :  {'neg': 0.0, 'neu': 0.906, 'pos': 0.094, 'compound': 0.34}
# salesforce tweets :  {'neg': 0.0, 'neu': 0.744, 'pos': 0.256, 'compound': 0.4767}
# salesforce tweets :  {'neg': 0.0, 'neu': 0.823, 'pos': 0.177, 'compound': 0.6239}
# salesforce tweets :  {'neg': 0.0, 'neu': 0.68, 'pos': 0.32, 'compound': 0.8555}
# salesforce tweets :  {'neg': 0.0, 'neu': 0.893, 'pos': 0.107, 'compound': 0.34}
# salesforce tweets :  {'neg': 0.0, 'neu': 1.0, 'pos': 0.0, 'compound': 0.0}
# salesforce tweets :  {'neg': 0.0, 'neu': 0.749, 'pos': 0.251, 'compound': 0.6892}
# salesforce tweets :  {'neg': 0.119, 'neu': 0.881, 'pos': 0.0, 'compound': -0.4019}
# salesforce tweets :  {'neg': 0.0, 'neu': 0.719, 'pos': 0.281, 'compound': 0.6892}
# salesforce tweets :  {'neg': 0.0, 'neu': 0.766, 'pos': 0.234, 'compound': 0.6369}
# salesforce tweets :  {'neg': 0.0, 'neu': 0.68, 'pos': 0.32, 'compound': 0.8555}
# salesforce tweets :  {'neg': 0.0, 'neu': 1.0, 'pos': 0.0, 'compound': 0.0}
# salesforce tweets :  {'neg': 0.0, 'neu': 1.0, 'pos': 0.0, 'compound': 0.0}
# salesforce tweets :  {'neg': 0.0, 'neu': 1.0, 'pos': 0.0, 'compound': 0.0}
# salesforce tweets :  {'neg': 0.0, 'neu': 1.0, 'pos': 0.0, 'compound': 0.0}
# salesforce tweets :  {'neg': 0.0, 'neu': 1.0, 'pos': 0.0, 'compound': 0.0}
# salesforce tweets :  {'neg': 0.0, 'neu': 0.882, 'pos': 0.118, 'compound': 0.25}
# salesforce tweets :  {'neg': 0.0, 'neu': 0.658, 'pos': 0.342, 'compound': 0.8313}
# salesforce tweets :  {'neg': 0.0, 'neu': 0.702, 'pos': 0.298, 'compound': 0.5267}
# salesforce tweets :  {'neg': 0.0, 'neu': 1.0, 'pos': 0.0, 'compound': 0.0}
# salesforce tweets :  {'neg': 0.0, 'neu': 0.625, 'pos': 0.375, 'compound': 0.8313}
# salesforce tweets :  {'neg': 0.0, 'neu': 1.0, 'pos': 0.0, 'compound': 0.0}
# salesforce tweets :  {'neg': 0.0, 'neu': 1.0, 'pos': 0.0, 'compound': 0.0}
# salesforce tweets :  {'neg': 0.0, 'neu': 1.0, 'pos': 0.0, 'compound': 0.0}
# salesforce tweets :  {'neg': 0.0, 'neu': 1.0, 'pos': 0.0, 'compound': 0.0}
# salesforce tweets :  {'neg': 0.0, 'neu': 0.781, 'pos': 0.219, 'compound': 0.4753}
# salesforce tweets :  {'neg': 0.0, 'neu': 0.805, 'pos': 0.195, 'compound': 0.5242}
# salesforce tweets :  {'neg': 0.0, 'neu': 0.805, 'pos': 0.195, 'compound': 0.5242}
# salesforce tweets :  {'neg': 0.0, 'neu': 0.805, 'pos': 0.195, 'compound': 0.5242}
# salesforce tweets :  {'neg': 0.0, 'neu': 0.805, 'pos': 0.195, 'compound': 0.5242}
# salesforce tweets :  {'neg': 0.0, 'neu': 1.0, 'pos': 0.0, 'compound': 0.0}
# salesforce tweets :  {'neg': 0.0, 'neu': 1.0, 'pos': 0.0, 'compound': 0.0}
# salesforce tweets :  {'neg': 0.0, 'neu': 0.839, 'pos': 0.161, 'compound': 0.3612}
# salesforce tweets :  {'neg': 0.0, 'neu': 0.769, 'pos': 0.231, 'compound': 0.5574}
# salesforce tweets :  {'neg': 0.0, 'neu': 1.0, 'pos': 0.0, 'compound': 0.0}
# salesforce tweets :  {'neg': 0.0, 'neu': 1.0, 'pos': 0.0, 'compound': 0.0}
# salesforce tweets :  {'neg': 0.0, 'neu': 1.0, 'pos': 0.0, 'compound': 0.0}
# salesforce tweets :  {'neg': 0.085, 'neu': 0.915, 'pos': 0.0, 'compound': -0.1027}
# salesforce tweets :  {'neg': 0.198, 'neu': 0.802, 'pos': 0.0, 'compound': -0.6652}
# salesforce tweets :  {'neg': 0.0, 'neu': 1.0, 'pos': 0.0, 'compound': 0.0}
# salesforce tweets :  {'neg': 0.0, 'neu': 0.396, 'pos': 0.604, 'compound': 0.7269}
# salesforce tweets :  {'neg': 0.0, 'neu': 1.0, 'pos': 0.0, 'compound': 0.0}
# salesforce tweets :  {'neg': 0.0, 'neu': 1.0, 'pos': 0.0, 'compound': 0.0}
# salesforce tweets :  {'neg': 0.0, 'neu': 1.0, 'pos': 0.0, 'compound': 0.0}
# salesforce tweets :  {'neg': 0.198, 'neu': 0.802, 'pos': 0.0, 'compound': -0.6652}
# salesforce tweets :  {'neg': 0.0, 'neu': 1.0, 'pos': 0.0, 'compound': 0.0}
# salesforce tweets :  {'neg': 0.0, 'neu': 0.654, 'pos': 0.346, 'compound': 0.6486}
# salesforce tweets :  {'neg': 0.198, 'neu': 0.802, 'pos': 0.0, 'compound': -0.6652}
# salesforce tweets :  {'neg': 0.082, 'neu': 0.773, 'pos': 0.146, 'compound': 0.3595}
# salesforce tweets :  {'neg': 0.0, 'neu': 1.0, 'pos': 0.0, 'compound': 0.0}
# salesforce tweets :  {'neg': 0.0, 'neu': 0.793, 'pos': 0.207, 'compound': 0.5242}
# salesforce tweets :  {'neg': 0.0, 'neu': 0.805, 'pos': 0.195, 'compound': 0.5242}
# salesforce tweets :  {'neg': 0.0, 'neu': 0.793, 'pos': 0.207, 'compound': 0.34}
# salesforce tweets :  {'neg': 0.0, 'neu': 1.0, 'pos': 0.0, 'compound': 0.0}
# salesforce tweets :  {'neg': 0.082, 'neu': 0.773, 'pos': 0.146, 'compound': 0.3595}
# salesforce tweets :  {'neg': 0.0, 'neu': 1.0, 'pos': 0.0, 'compound': 0.0}
# salesforce tweets :  {'neg': 0.0, 'neu': 0.782, 'pos': 0.218, 'compound': 0.5994}
# salesforce tweets :  {'neg': 0.0, 'neu': 1.0, 'pos': 0.0, 'compound': 0.0}
# salesforce tweets :  {'neg': 0.0, 'neu': 0.881, 'pos': 0.119, 'compound': 0.3182}
# salesforce tweets :  {'neg': 0.122, 'neu': 0.878, 'pos': 0.0, 'compound': -0.3595}
# salesforce tweets :  {'neg': 0.0, 'neu': 0.755, 'pos': 0.245, 'compound': 0.636}
# salesforce tweets :  {'neg': 0.0, 'neu': 1.0, 'pos': 0.0, 'compound': 0.0}
# salesforce tweets :  {'neg': 0.0, 'neu': 0.784, 'pos': 0.216, 'compound': 0.6892}
# salesforce tweets :  {'neg': 0.0, 'neu': 0.805, 'pos': 0.195, 'compound': 0.5574}
# salesforce tweets :  {'neg': 0.0, 'neu': 0.892, 'pos': 0.108, 'compound': 0.1779}
# salesforce tweets :  {'neg': 0.0, 'neu': 0.714, 'pos': 0.286, 'compound': 0.4215}
# salesforce tweets :  {'neg': 0.0, 'neu': 0.664, 'pos': 0.336, 'compound': 0.765}
# salesforce tweets :  {'neg': 0.0, 'neu': 1.0, 'pos': 0.0, 'compound': 0.0}
# salesforce tweets :  {'neg': 0.0, 'neu': 1.0, 'pos': 0.0, 'compound': 0.0}
# salesforce tweets :  {'neg': 0.0, 'neu': 0.817, 'pos': 0.183, 'compound': 0.6696}
# salesforce tweets :  {'neg': 0.0, 'neu': 0.623, 'pos': 0.377, 'compound': 0.8834}
# salesforce tweets :  {'neg': 0.0, 'neu': 1.0, 'pos': 0.0, 'compound': 0.0}
# salesforce tweets :  {'neg': 0.149, 'neu': 0.851, 'pos': 0.0, 'compound': -0.3129}
# salesforce tweets :  {'neg': 0.0, 'neu': 0.762, 'pos': 0.238, 'compound': 0.6892}
# salesforce tweets :  {'neg': 0.0, 'neu': 0.793, 'pos': 0.207, 'compound': 0.5242}
# salesforce tweets :  {'neg': 0.0, 'neu': 0.805, 'pos': 0.195, 'compound': 0.5242}
# salesforce tweets :  {'neg': 0.0, 'neu': 0.647, 'pos': 0.353, 'compound': 0.7955}
# salesforce tweets :  {'neg': 0.0, 'neu': 0.821, 'pos': 0.179, 'compound': 0.5719}
# salesforce tweets :  {'neg': 0.415, 'neu': 0.585, 'pos': 0.0, 'compound': -0.7964}
# salesforce tweets :  {'neg': 0.0, 'neu': 0.914, 'pos': 0.086, 'compound': 0.1511}
# salesforce tweets :  {'neg': 0.0, 'neu': 0.909, 'pos': 0.091, 'compound': 0.296}
# salesforce tweets :  {'neg': 0.0, 'neu': 0.896, 'pos': 0.104, 'compound': 0.296}
# salesforce tweets :  {'neg': 0.0, 'neu': 1.0, 'pos': 0.0, 'compound': 0.0}
# salesforce tweets :  {'neg': 0.0, 'neu': 0.606, 'pos': 0.394, 'compound': 0.7579}
# salesforce tweets :  {'neg': 0.0, 'neu': 0.87, 'pos': 0.13, 'compound': 0.4019}
# salesforce tweets :  {'neg': 0.0, 'neu': 0.8, 'pos': 0.2, 'compound': 0.6115}
# salesforce tweets :  {'neg': 0.0, 'neu': 0.903, 'pos': 0.097, 'compound': 0.3802}
# salesforce tweets :  {'neg': 0.0, 'neu': 1.0, 'pos': 0.0, 'compound': 0.0}
# salesforce tweets :  {'neg': 0.0, 'neu': 0.89, 'pos': 0.11, 'compound': 0.3802}
# salesforce tweets :  {'neg': 0.0, 'neu': 0.725, 'pos': 0.275, 'compound': 0.7804}
# salesforce tweets :  {'neg': 0.0, 'neu': 0.586, 'pos': 0.414, 'compound': 0.8585}
#
# AWS tweets :  {'neg': 0.0, 'neu': 0.909, 'pos': 0.091, 'compound': 0.1779}
# AWS tweets :  {'neg': 0.146, 'neu': 0.854, 'pos': 0.0, 'compound': -0.4404}
# AWS tweets :  {'neg': 0.0, 'neu': 0.909, 'pos': 0.091, 'compound': 0.1779}
# AWS tweets :  {'neg': 0.0, 'neu': 1.0, 'pos': 0.0, 'compound': 0.0}
# AWS tweets :  {'neg': 0.0, 'neu': 1.0, 'pos': 0.0, 'compound': 0.0}
# AWS tweets :  {'neg': 0.0, 'neu': 0.909, 'pos': 0.091, 'compound': 0.1779}
# AWS tweets :  {'neg': 0.0, 'neu': 0.909, 'pos': 0.091, 'compound': 0.1779}
# AWS tweets :  {'neg': 0.0, 'neu': 0.909, 'pos': 0.091, 'compound': 0.1779}
# AWS tweets :  {'neg': 0.0, 'neu': 0.892, 'pos': 0.108, 'compound': 0.1779}
# AWS tweets :  {'neg': 0.0, 'neu': 0.833, 'pos': 0.167, 'compound': 0.4939}
# AWS tweets :  {'neg': 0.0, 'neu': 0.877, 'pos': 0.123, 'compound': 0.4215}
# AWS tweets :  {'neg': 0.11, 'neu': 0.89, 'pos': 0.0, 'compound': -0.3818}
# AWS tweets :  {'neg': 0.126, 'neu': 0.874, 'pos': 0.0, 'compound': -0.3818}
# AWS tweets :  {'neg': 0.205, 'neu': 0.64, 'pos': 0.155, 'compound': -0.3595}
# AWS tweets :  {'neg': 0.144, 'neu': 0.856, 'pos': 0.0, 'compound': -0.4019}
# AWS tweets :  {'neg': 0.0, 'neu': 1.0, 'pos': 0.0, 'compound': 0.0}
# AWS tweets :  {'neg': 0.0, 'neu': 1.0, 'pos': 0.0, 'compound': 0.0}
# AWS tweets :  {'neg': 0.0, 'neu': 0.734, 'pos': 0.266, 'compound': 0.6996}
# AWS tweets :  {'neg': 0.0, 'neu': 0.867, 'pos': 0.133, 'compound': 0.3818}
# AWS tweets :  {'neg': 0.0, 'neu': 1.0, 'pos': 0.0, 'compound': 0.0}
# AWS tweets :  {'neg': 0.0, 'neu': 1.0, 'pos': 0.0, 'compound': 0.0}
# AWS tweets :  {'neg': 0.0, 'neu': 1.0, 'pos': 0.0, 'compound': 0.0}
# AWS tweets :  {'neg': 0.0, 'neu': 0.884, 'pos': 0.116, 'compound': 0.1779}
# AWS tweets :  {'neg': 0.146, 'neu': 0.854, 'pos': 0.0, 'compound': -0.4404}
# AWS tweets :  {'neg': 0.168, 'neu': 0.594, 'pos': 0.237, 'compound': 0.1007}
# AWS tweets :  {'neg': 0.0, 'neu': 1.0, 'pos': 0.0, 'compound': 0.0}
# AWS tweets :  {'neg': 0.0, 'neu': 1.0, 'pos': 0.0, 'compound': 0.0}
# AWS tweets :  {'neg': 0.0, 'neu': 1.0, 'pos': 0.0, 'compound': 0.0}
# AWS tweets :  {'neg': 0.0, 'neu': 1.0, 'pos': 0.0, 'compound': 0.0}
# AWS tweets :  {'neg': 0.0, 'neu': 1.0, 'pos': 0.0, 'compound': 0.0}
# AWS tweets :  {'neg': 0.0, 'neu': 1.0, 'pos': 0.0, 'compound': 0.0}
# AWS tweets :  {'neg': 0.0, 'neu': 1.0, 'pos': 0.0, 'compound': 0.0}
# AWS tweets :  {'neg': 0.0, 'neu': 1.0, 'pos': 0.0, 'compound': 0.0}
# AWS tweets :  {'neg': 0.0, 'neu': 1.0, 'pos': 0.0, 'compound': 0.0}
# AWS tweets :  {'neg': 0.0, 'neu': 1.0, 'pos': 0.0, 'compound': 0.0}
# AWS tweets :  {'neg': 0.0, 'neu': 1.0, 'pos': 0.0, 'compound': 0.0}
# AWS tweets :  {'neg': 0.0, 'neu': 0.775, 'pos': 0.225, 'compound': 0.4404}
# AWS tweets :  {'neg': 0.0, 'neu': 1.0, 'pos': 0.0, 'compound': 0.0}
# AWS tweets :  {'neg': 0.0, 'neu': 0.904, 'pos': 0.096, 'compound': 0.1779}
# AWS tweets :  {'neg': 0.0, 'neu': 1.0, 'pos': 0.0, 'compound': 0.0}
# AWS tweets :  {'neg': 0.0, 'neu': 0.904, 'pos': 0.096, 'compound': 0.1779}
# AWS tweets :  {'neg': 0.0, 'neu': 0.872, 'pos': 0.128, 'compound': 0.3612}
# AWS tweets :  {'neg': 0.0, 'neu': 0.881, 'pos': 0.119, 'compound': 0.4019}
# AWS tweets :  {'neg': 0.0, 'neu': 0.709, 'pos': 0.291, 'compound': 0.4019}
# AWS tweets :  {'neg': 0.0, 'neu': 1.0, 'pos': 0.0, 'compound': 0.0}
# AWS tweets :  {'neg': 0.0, 'neu': 0.603, 'pos': 0.397, 'compound': 0.7845}
# AWS tweets :  {'neg': 0.0, 'neu': 1.0, 'pos': 0.0, 'compound': 0.0}
# AWS tweets :  {'neg': 0.0, 'neu': 1.0, 'pos': 0.0, 'compound': 0.0}
# AWS tweets :  {'neg': 0.0, 'neu': 0.806, 'pos': 0.194, 'compound': 0.4767}
# AWS tweets :  {'neg': 0.0, 'neu': 1.0, 'pos': 0.0, 'compound': 0.0}
# AWS tweets :  {'neg': 0.158, 'neu': 0.842, 'pos': 0.0, 'compound': -0.4588}
# AWS tweets :  {'neg': 0.0, 'neu': 1.0, 'pos': 0.0, 'compound': 0.0}
# AWS tweets :  {'neg': 0.0, 'neu': 1.0, 'pos': 0.0, 'compound': 0.0}
# AWS tweets :  {'neg': 0.182, 'neu': 0.818, 'pos': 0.0, 'compound': -0.25}
# AWS tweets :  {'neg': 0.0, 'neu': 1.0, 'pos': 0.0, 'compound': 0.0}
# AWS tweets :  {'neg': 0.0, 'neu': 1.0, 'pos': 0.0, 'compound': 0.0}
# AWS tweets :  {'neg': 0.0, 'neu': 1.0, 'pos': 0.0, 'compound': 0.0}
# AWS tweets :  {'neg': 0.0, 'neu': 1.0, 'pos': 0.0, 'compound': 0.0}
# AWS tweets :  {'neg': 0.0, 'neu': 1.0, 'pos': 0.0, 'compound': 0.0}
# AWS tweets :  {'neg': 0.0, 'neu': 0.737, 'pos': 0.263, 'compound': 0.6124}
# AWS tweets :  {'neg': 0.0, 'neu': 0.826, 'pos': 0.174, 'compound': 0.4939}
# AWS tweets :  {'neg': 0.205, 'neu': 0.64, 'pos': 0.155, 'compound': -0.3595}
# AWS tweets :  {'neg': 0.0, 'neu': 0.862, 'pos': 0.138, 'compound': 0.34}
# AWS tweets :  {'neg': 0.0, 'neu': 1.0, 'pos': 0.0, 'compound': 0.0}
# AWS tweets :  {'neg': 0.0, 'neu': 1.0, 'pos': 0.0, 'compound': 0.0}
# AWS tweets :  {'neg': 0.0, 'neu': 1.0, 'pos': 0.0, 'compound': 0.0}
# AWS tweets :  {'neg': 0.0, 'neu': 1.0, 'pos': 0.0, 'compound': 0.0}
# AWS tweets :  {'neg': 0.0, 'neu': 0.827, 'pos': 0.173, 'compound': 0.5574}
# AWS tweets :  {'neg': 0.0, 'neu': 1.0, 'pos': 0.0, 'compound': 0.0}
# AWS tweets :  {'neg': 0.0, 'neu': 1.0, 'pos': 0.0, 'compound': 0.0}
# AWS tweets :  {'neg': 0.0, 'neu': 1.0, 'pos': 0.0, 'compound': 0.0}
# AWS tweets :  {'neg': 0.0, 'neu': 1.0, 'pos': 0.0, 'compound': 0.0}
# AWS tweets :  {'neg': 0.0, 'neu': 0.8, 'pos': 0.2, 'compound': 0.128}
# AWS tweets :  {'neg': 0.0, 'neu': 0.879, 'pos': 0.121, 'compound': 0.296}
# AWS tweets :  {'neg': 0.0, 'neu': 1.0, 'pos': 0.0, 'compound': 0.0}
# AWS tweets :  {'neg': 0.0, 'neu': 0.848, 'pos': 0.152, 'compound': 0.5267}
# AWS tweets :  {'neg': 0.0, 'neu': 1.0, 'pos': 0.0, 'compound': 0.0}
# AWS tweets :  {'neg': 0.0, 'neu': 1.0, 'pos': 0.0, 'compound': 0.0}
# AWS tweets :  {'neg': 0.0, 'neu': 0.714, 'pos': 0.286, 'compound': 0.5574}
# AWS tweets :  {'neg': 0.2, 'neu': 0.8, 'pos': 0.0, 'compound': -0.3612}
# AWS tweets :  {'neg': 0.0, 'neu': 0.734, 'pos': 0.266, 'compound': 0.6996}
# AWS tweets :  {'neg': 0.0, 'neu': 0.892, 'pos': 0.108, 'compound': 0.1779}
# AWS tweets :  {'neg': 0.0, 'neu': 0.747, 'pos': 0.253, 'compound': 0.5267}
# AWS tweets :  {'neg': 0.0, 'neu': 0.734, 'pos': 0.266, 'compound': 0.6996}
# AWS tweets :  {'neg': 0.0, 'neu': 0.709, 'pos': 0.291, 'compound': 0.6249}
# AWS tweets :  {'neg': 0.205, 'neu': 0.64, 'pos': 0.155, 'compound': -0.3595}
# AWS tweets :  {'neg': 0.0, 'neu': 0.796, 'pos': 0.204, 'compound': 0.6249}
# AWS tweets :  {'neg': 0.0, 'neu': 1.0, 'pos': 0.0, 'compound': 0.0}
# AWS tweets :  {'neg': 0.0, 'neu': 0.87, 'pos': 0.13, 'compound': 0.34}
# AWS tweets :  {'neg': 0.0, 'neu': 0.856, 'pos': 0.144, 'compound': 0.4019}
# AWS tweets :  {'neg': 0.0, 'neu': 1.0, 'pos': 0.0, 'compound': 0.0}
# AWS tweets :  {'neg': 0.0, 'neu': 1.0, 'pos': 0.0, 'compound': 0.0}
# AWS tweets :  {'neg': 0.158, 'neu': 0.842, 'pos': 0.0, 'compound': -0.4588}
# AWS tweets :  {'neg': 0.0, 'neu': 1.0, 'pos': 0.0, 'compound': 0.0}
# AWS tweets :  {'neg': 0.0, 'neu': 1.0, 'pos': 0.0, 'compound': 0.0}
# AWS tweets :  {'neg': 0.0, 'neu': 1.0, 'pos': 0.0, 'compound': 0.0}
# AWS tweets :  {'neg': 0.0, 'neu': 0.796, 'pos': 0.204, 'compound': 0.6249}
# AWS tweets :  {'neg': 0.0, 'neu': 0.773, 'pos': 0.227, 'compound': 0.6249}
# AWS tweets :  {'neg': 0.0, 'neu': 0.852, 'pos': 0.148, 'compound': 0.3818}
# AWS tweets :  {'neg': 0.0, 'neu': 0.87, 'pos': 0.13, 'compound': 0.4019}

# %%
from mpl_toolkits.mplot3d import Axes3D
import matplotlib.pyplot as plt


#build our figure
fig = plt.figure()
#build axes
ax=fig.add_subplot(111,projection='3d')

sentiments = [get_sentiments(tweet.text) for tweet in Azure]


xs=[]
for sent in sentiments:
    xs.append(sent['neg'])
    
ys=[sent['neu'] for sent in sentiments]

zs = list(map(lambda x:x['pos'],sentiments))

ax.scatter(xs,ys,zs)

from nltk_helper import split_sentiments

vX,vY,vZ = split_sentiments([get_sentiments(tweet.text) for tweet in tweepy.Cursor(api.search,q="#salesforce",
                           lang="en").items(100)])
  
ax.scatter(vX,vY,vZ, color='r',marker='*')

ax.set_xlabel('Negative')
ax.set_ylabel('neutral')
ax.set_zlabel('postive')




zX,zY,zZ = split_sentiments([get_sentiments(tweet.text) for tweet in tweepy.Cursor(api.search,q="#AWS",
                           lang="en").items(100)])
ax.scatter(zX,zY,zZ, color='g',marker='d')
ax.scatter(zX,zY,zZ)

ax.scatter(xs,ys,zs)
ax.set_xlabel('Negative')
ax.set_ylabel('neutral')
ax.set_zlabel('postive')

plt.show()

# %%
from nltk.sentiment.vader import SentimentIntensityAnalyzer
analyzer = SentimentIntensityAnalyzer()

positive1 = []
negative1 = []
neutral1 = []
for tweet in tweepy.Cursor(api.search,q="#Azure",
                           lang="en").items(100):   
    if(analyzer.polarity_scores(tweet.text)['compound']) >=0.5:        
        positive1.append(tweet.text)
    elif(analyzer.polarity_scores(tweet.text)['compound']) <= -0.5:        
        negative1.append(tweet.text)
    else:
        neutral1.append(tweet.text) 
        

        
positive2 = []
negative2 = []
neutral2 = []       
for tweet in tweepy.Cursor(api.search,q="#salesforce",
                           lang="en").items(100):   
    if(analyzer.polarity_scores(tweet.text)['compound']) >=0.5:        
        positive2.append(tweet.text)
    elif(analyzer.polarity_scores(tweet.text)['compound']) <= -0.5:        
        negative2.append(tweet.text)
    else:
        neutral2.append(tweet.text)  

positive3 = []
negative3 = []
neutral3 = []
for tweet in tweepy.Cursor(api.search,q="#AWS",
                           lang="en").items(100):   
    if(analyzer.polarity_scores(tweet.text)['compound']) >=0.5:        
        positive3.append(tweet.text)
    elif(analyzer.polarity_scores(tweet.text)['compound']) <= -0.5:        
        negative3.append(tweet.text)
    else:
        neutral3.append(tweet.text)           


print()
total1=len(positive1)+len(negative1)+len(neutral1)
per_pos1=len(positive1)/total1*100
per_neg1=len(negative1)/total1*100
per_neu1=len(neutral1)/total1*100

print('percentage of positive tweets for Azure: ',per_pos1)
print('percentageof negative tweets for Azure: ',per_neg1)
print('percentage of neutral tweets for Azure: ',per_neu1)
print('---------------------------------------------')



total2=len(positive2)+len(negative2)+len(neutral2)
per_pos2=len(positive2)/total2*100
per_neg2=len(negative2)/total2*100
per_neu2=len(neutral2)/total2*100

print('percentage of positive tweets for salesforce: ',per_pos2)
print('percentage of negative tweets for salesforce: ',per_neg2)
print('percentage of neutral tweets for salesforce: ',per_neu2)
print('---------------------------------------------')
'''
print(positive2)
print(negative2)
print(neutral2)
'''

total3=len(positive3)+len(negative3)+len(neutral3)
per_pos3=len(positive3)/total3*100
per_neg3=len(negative3)/total3*100
per_neu3=len(neutral3)/total3*100

print('percentage of positive tweets for AWS: ',per_pos2)
print('percentage of negative tweets for AWS : ',per_neg2)
print('percentage of neutral tweets for AWS: ',per_neu2)
'''
print(positive3)
print(negative3)
print(neutral3)
'''
import matplotlib.pyplot as plt
 
# set width of bar
barWidth = 0.1
 
# set height of bar
'''
postiveFinal = [per_pos1,per_pos2,per_pos3]
negativeFinal = [per_neg1, per_neg2, per_neg3]
neutralFinal = [per_neu1, per_neu2, per_neu3]
'''
postiveFinal = [per_pos1,per_neg1,per_neu1]
negativeFinal = [per_pos2, per_neg2, per_neu2]
neutralFinal = [per_pos3, per_neg3, per_neu3]
 


fig = plt.figure()

plt.ylim(0, 100)

n=3

index=np.arange(n)

barwidth=0.25

opacity=0.8

objects=('Postive','Negative','Neutral')

 

rects1 = plt.bar(index, postiveFinal, barwidth,

alpha=opacity,

color='r',

label='Azure')

 

rects2 = plt.bar(index + barwidth, negativeFinal, barwidth,

alpha=opacity,

color='y',

label='salesforce')

 

 

rects3 = plt.bar(index +barwidth+ barwidth, neutralFinal, barwidth,

alpha=opacity,

color='b',

label='AWS')

 

 



plt.xticks(index + barwidth,objects)

plt.ylabel('units in percentage (%)')
plt.xlabel(' POLARITY CLASSIFICATION')           
           

plt.title('Trending Cloud Service Provider')
  

plt.legend()

plt.tight_layout()



 

plt.show()
# Out:
# percentage of positive tweets for Azure:  14.000000000000002
# percentageof negative tweets for Azure:  1.0
# percentage of neutral tweets for Azure:  85.0
# ---------------------------------------------
# percentage of positive tweets for salesforce:  35.0
# percentage of negative tweets for salesforce:  4.0
# percentage of neutral tweets for salesforce:  61.0
# ---------------------------------------------
# percentage of positive tweets for AWS:  35.0
# percentage of negative tweets for AWS :  4.0
# percentage of neutral tweets for AWS:  61.0
