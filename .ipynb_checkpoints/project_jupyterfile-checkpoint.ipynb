# %% [markdown]
# ## Student Name : Bhuvanesh Nakka
#
#
# ## Project Narration :
#
# ### Project Proposal
# From the tweets and reviews of the  top two cloud service providers namely AWS and Azure concluding the best cloud service provider .
#
#
# ### Focus
# Cloud computing services cover a vast range of options now from the basics of storage, networking and processing power , So people are interested to choose the best cloud service provide which will satisfy their requirements . This is the tool which help the people to choose service provider which help them in taking the decision among Azure,AWS and Salesforce.
#
# ### Retrieval of Data
# This tool retrives the tweets from the top three cloud service providers namely #Azure,#salesforce and # AWS ,By the sentimental analysis method the polarity of the tweets are calculated and then project the results in the bargraph from that we can conclude the the current trending cloud service provider. Here i had used first 100 tweets from the three hashtags to conduct the sentimental analysis and stored them in the CSV files.

# %% [markdown]
# ### Analysis of the steps :
#
# 1. Import the required libraries and packages for the project and set connection to the twitter.
# 2. Create three CSV files namely azure.csv, salesforce.csv and AWS.csv to which the  tweets are stored.
# 3. Conduct the sentimental analysis for the 300 tweets which we retrieved from the three hashtags.
# 4. Give the polarity conditions to seperate the tweets from positive negative or neutral tweets.
# 5. From the imported libraries create a barchart with specified requiremnets  which will visualize the results.
# 5. From the results we can conclude the trending cloud service provider at the particular momment.

# %%
import tweepy
import csv
#import pandas as pd
#import datetime
from twitter_keys import consumer_key, consumer_secret, access_token, access_secret
#import pickle
import matplotlib.pyplot as plt; plt.rcdefaults()
import numpy as np
import matplotlib.pyplot as plt


auth = tweepy.OAuthHandler(consumer_key,consumer_secret)
auth.set_access_token(access_token,access_secret)

api = tweepy.API(auth)

# %%
csvFile = open('azure.csv', 'w')

csvWriter = csv.writer(csvFile)

for tweet in tweepy.Cursor(api.search,q="#Azure",
                           lang="en").items(100):
    #print (tweet.text)
    csvWriter.writerow([tweet.text.encode('utf-8')])
    

    
from nltk_helper import get_sentiments
    


for tweet in tweepy.Cursor(api.search,q="#Azure",
                           lang="en").items(100):
    print("Azure tweets : ",get_sentiments(tweet.text))
print()


Azure=tweepy.Cursor(api.search,q="#Azure",
                           lang="en").items(100)


# salesforce

csvFile = open('salesforce.csv', 'w')

csvWriter = csv.writer(csvFile)


for tweet in tweepy.Cursor(api.search,q="#salesforce",
                           lang="en").items(100):
    #print (tweet.text)
    csvWriter.writerow([tweet.text.encode('utf-8')])
    

    
from nltk_helper import get_sentiments
    


for tweet in tweepy.Cursor(api.search,q="#salesforce",
                           lang="en").items(100):
    print("salesforce tweets : ",get_sentiments(tweet.text))
print()


salesforce=tweepy.Cursor(api.search,q="#salesforce",
                           lang="en").items(100)


#AWS

csvFile = open('AWS.csv', 'w')

csvWriter = csv.writer(csvFile)

for tweet in tweepy.Cursor(api.search,q="#AWS",
                           lang="en").items(100):
    #print (tweet.text)
    csvWriter.writerow([tweet.text.encode('utf-8')])
    

    
from nltk_helper import get_sentiments
    

for tweet in tweepy.Cursor(api.search,q="#AWS",lang="en").items(100):
                           
                           print("AWS tweets : ",get_sentiments(tweet.text))
    
print()


AWS=tweepy.Cursor(api.search,q="#AWS",
                           lang="en").items(100)
# Out:
# [nltk_data] Downloading package vader_lexicon to
# [nltk_data]     C:\Users\s534846\AppData\Roaming\nltk_data...
# [nltk_data]   Package vader_lexicon is already up-to-date!
# Azure tweets :  {'neg': 0.0, 'neu': 0.818, 'pos': 0.182, 'compound': 0.4404}
# Azure tweets :  {'neg': 0.0, 'neu': 1.0, 'pos': 0.0, 'compound': 0.0}
# Azure tweets :  {'neg': 0.0, 'neu': 1.0, 'pos': 0.0, 'compound': 0.0}
# Azure tweets :  {'neg': 0.0, 'neu': 1.0, 'pos': 0.0, 'compound': 0.0}
# Azure tweets :  {'neg': 0.0, 'neu': 1.0, 'pos': 0.0, 'compound': 0.0}
# Azure tweets :  {'neg': 0.0, 'neu': 1.0, 'pos': 0.0, 'compound': 0.0}
# Azure tweets :  {'neg': 0.0, 'neu': 1.0, 'pos': 0.0, 'compound': 0.0}
# Azure tweets :  {'neg': 0.0, 'neu': 1.0, 'pos': 0.0, 'compound': 0.0}
# Azure tweets :  {'neg': 0.0, 'neu': 0.843, 'pos': 0.157, 'compound': 0.4215}
# Azure tweets :  {'neg': 0.0, 'neu': 1.0, 'pos': 0.0, 'compound': 0.0}
# Azure tweets :  {'neg': 0.261, 'neu': 0.619, 'pos': 0.119, 'compound': -0.4939}
# Azure tweets :  {'neg': 0.0, 'neu': 0.734, 'pos': 0.266, 'compound': 0.6988}
# Azure tweets :  {'neg': 0.0, 'neu': 1.0, 'pos': 0.0, 'compound': 0.0}
# Azure tweets :  {'neg': 0.0, 'neu': 1.0, 'pos': 0.0, 'compound': 0.0}
# Azure tweets :  {'neg': 0.0, 'neu': 1.0, 'pos': 0.0, 'compound': 0.0}
# Azure tweets :  {'neg': 0.0, 'neu': 1.0, 'pos': 0.0, 'compound': 0.0}
# Azure tweets :  {'neg': 0.0, 'neu': 1.0, 'pos': 0.0, 'compound': 0.0}
# Azure tweets :  {'neg': 0.0, 'neu': 1.0, 'pos': 0.0, 'compound': 0.0}
# Azure tweets :  {'neg': 0.0, 'neu': 1.0, 'pos': 0.0, 'compound': 0.0}
# Azure tweets :  {'neg': 0.0, 'neu': 1.0, 'pos': 0.0, 'compound': 0.0}
# Azure tweets :  {'neg': 0.0, 'neu': 1.0, 'pos': 0.0, 'compound': 0.0}
# Azure tweets :  {'neg': 0.0, 'neu': 1.0, 'pos': 0.0, 'compound': 0.0}
# Azure tweets :  {'neg': 0.0, 'neu': 1.0, 'pos': 0.0, 'compound': 0.0}
# Azure tweets :  {'neg': 0.0, 'neu': 0.856, 'pos': 0.144, 'compound': 0.4926}
# Azure tweets :  {'neg': 0.057, 'neu': 0.943, 'pos': 0.0, 'compound': -0.1027}
# Azure tweets :  {'neg': 0.0, 'neu': 1.0, 'pos': 0.0, 'compound': 0.0}
# Azure tweets :  {'neg': 0.0, 'neu': 1.0, 'pos': 0.0, 'compound': 0.0}
# Azure tweets :  {'neg': 0.188, 'neu': 0.812, 'pos': 0.0, 'compound': -0.4588}
# Azure tweets :  {'neg': 0.0, 'neu': 1.0, 'pos': 0.0, 'compound': 0.0}
# Azure tweets :  {'neg': 0.0, 'neu': 1.0, 'pos': 0.0, 'compound': 0.0}
# Azure tweets :  {'neg': 0.0, 'neu': 1.0, 'pos': 0.0, 'compound': 0.0}
# Azure tweets :  {'neg': 0.0, 'neu': 1.0, 'pos': 0.0, 'compound': 0.0}
# Azure tweets :  {'neg': 0.0, 'neu': 1.0, 'pos': 0.0, 'compound': 0.0}
# Azure tweets :  {'neg': 0.0, 'neu': 1.0, 'pos': 0.0, 'compound': 0.0}
# Azure tweets :  {'neg': 0.0, 'neu': 0.714, 'pos': 0.286, 'compound': 0.7783}
# Azure tweets :  {'neg': 0.0, 'neu': 1.0, 'pos': 0.0, 'compound': 0.0}
# Azure tweets :  {'neg': 0.0, 'neu': 1.0, 'pos': 0.0, 'compound': 0.0}
# Azure tweets :  {'neg': 0.0, 'neu': 1.0, 'pos': 0.0, 'compound': 0.0}
# Azure tweets :  {'neg': 0.0, 'neu': 1.0, 'pos': 0.0, 'compound': 0.0}
# Azure tweets :  {'neg': 0.042, 'neu': 0.694, 'pos': 0.264, 'compound': 0.829}
# Azure tweets :  {'neg': 0.0, 'neu': 1.0, 'pos': 0.0, 'compound': 0.0}
# Azure tweets :  {'neg': 0.0, 'neu': 1.0, 'pos': 0.0, 'compound': 0.0}
# Azure tweets :  {'neg': 0.0, 'neu': 1.0, 'pos': 0.0, 'compound': 0.0}
# Azure tweets :  {'neg': 0.0, 'neu': 0.891, 'pos': 0.109, 'compound': 0.296}
# Azure tweets :  {'neg': 0.0, 'neu': 0.809, 'pos': 0.191, 'compound': 0.6369}
# Azure tweets :  {'neg': 0.105, 'neu': 0.776, 'pos': 0.119, 'compound': 0.0772}
# Azure tweets :  {'neg': 0.0, 'neu': 1.0, 'pos': 0.0, 'compound': 0.0}
# Azure tweets :  {'neg': 0.0, 'neu': 1.0, 'pos': 0.0, 'compound': 0.0}
# Azure tweets :  {'neg': 0.0, 'neu': 1.0, 'pos': 0.0, 'compound': 0.0}
# Azure tweets :  {'neg': 0.0, 'neu': 1.0, 'pos': 0.0, 'compound': 0.0}
# Azure tweets :  {'neg': 0.0, 'neu': 1.0, 'pos': 0.0, 'compound': 0.0}
# Azure tweets :  {'neg': 0.0, 'neu': 1.0, 'pos': 0.0, 'compound': 0.0}
# Azure tweets :  {'neg': 0.0, 'neu': 1.0, 'pos': 0.0, 'compound': 0.0}
# Azure tweets :  {'neg': 0.0, 'neu': 1.0, 'pos': 0.0, 'compound': 0.0}
# Azure tweets :  {'neg': 0.0, 'neu': 1.0, 'pos': 0.0, 'compound': 0.0}
# Azure tweets :  {'neg': 0.0, 'neu': 0.829, 'pos': 0.171, 'compound': 0.4767}
# Azure tweets :  {'neg': 0.0, 'neu': 0.688, 'pos': 0.312, 'compound': 0.7783}
# Azure tweets :  {'neg': 0.0, 'neu': 1.0, 'pos': 0.0, 'compound': 0.0}
# Azure tweets :  {'neg': 0.0, 'neu': 1.0, 'pos': 0.0, 'compound': 0.0}
# Azure tweets :  {'neg': 0.0, 'neu': 1.0, 'pos': 0.0, 'compound': 0.0}
# Azure tweets :  {'neg': 0.0, 'neu': 0.796, 'pos': 0.204, 'compound': 0.5262}
# Azure tweets :  {'neg': 0.0, 'neu': 1.0, 'pos': 0.0, 'compound': 0.0}
# Azure tweets :  {'neg': 0.0, 'neu': 1.0, 'pos': 0.0, 'compound': 0.0}
# Azure tweets :  {'neg': 0.0, 'neu': 1.0, 'pos': 0.0, 'compound': 0.0}
# Azure tweets :  {'neg': 0.0, 'neu': 0.896, 'pos': 0.104, 'compound': 0.296}
# Azure tweets :  {'neg': 0.0, 'neu': 1.0, 'pos': 0.0, 'compound': 0.0}
# Azure tweets :  {'neg': 0.0, 'neu': 1.0, 'pos': 0.0, 'compound': 0.0}
# Azure tweets :  {'neg': 0.0, 'neu': 0.856, 'pos': 0.144, 'compound': 0.4019}
# Azure tweets :  {'neg': 0.0, 'neu': 1.0, 'pos': 0.0, 'compound': 0.0}
# Azure tweets :  {'neg': 0.0, 'neu': 1.0, 'pos': 0.0, 'compound': 0.0}
# Azure tweets :  {'neg': 0.0, 'neu': 0.769, 'pos': 0.231, 'compound': 0.5106}
# Azure tweets :  {'neg': 0.072, 'neu': 0.928, 'pos': 0.0, 'compound': -0.1027}
# Azure tweets :  {'neg': 0.0, 'neu': 0.8, 'pos': 0.2, 'compound': 0.5411}
# Azure tweets :  {'neg': 0.0, 'neu': 0.876, 'pos': 0.124, 'compound': 0.4019}
# Azure tweets :  {'neg': 0.05, 'neu': 0.837, 'pos': 0.113, 'compound': 0.3612}
# Azure tweets :  {'neg': 0.0, 'neu': 1.0, 'pos': 0.0, 'compound': 0.0}
# Azure tweets :  {'neg': 0.0, 'neu': 1.0, 'pos': 0.0, 'compound': 0.0}
# Azure tweets :  {'neg': 0.117, 'neu': 0.693, 'pos': 0.19, 'compound': 0.1779}
# Azure tweets :  {'neg': 0.0, 'neu': 0.882, 'pos': 0.118, 'compound': 0.34}
# Azure tweets :  {'neg': 0.0, 'neu': 0.785, 'pos': 0.215, 'compound': 0.6369}
# Azure tweets :  {'neg': 0.0, 'neu': 1.0, 'pos': 0.0, 'compound': 0.0}
# Azure tweets :  {'neg': 0.0, 'neu': 0.734, 'pos': 0.266, 'compound': 0.784}
# Azure tweets :  {'neg': 0.0, 'neu': 1.0, 'pos': 0.0, 'compound': 0.0}
# Azure tweets :  {'neg': 0.0, 'neu': 0.829, 'pos': 0.171, 'compound': 0.4767}
# Azure tweets :  {'neg': 0.0, 'neu': 0.909, 'pos': 0.091, 'compound': 0.1779}
# Azure tweets :  {'neg': 0.0, 'neu': 1.0, 'pos': 0.0, 'compound': 0.0}
# Azure tweets :  {'neg': 0.0, 'neu': 0.781, 'pos': 0.219, 'compound': 0.4939}
# Azure tweets :  {'neg': 0.0, 'neu': 1.0, 'pos': 0.0, 'compound': 0.0}
# Azure tweets :  {'neg': 0.0, 'neu': 0.739, 'pos': 0.261, 'compound': 0.6486}
# Azure tweets :  {'neg': 0.0, 'neu': 0.73, 'pos': 0.27, 'compound': 0.6025}
# Azure tweets :  {'neg': 0.0, 'neu': 0.714, 'pos': 0.286, 'compound': 0.7351}
# Azure tweets :  {'neg': 0.0, 'neu': 1.0, 'pos': 0.0, 'compound': 0.0}
# Azure tweets :  {'neg': 0.0, 'neu': 1.0, 'pos': 0.0, 'compound': 0.0}
# Azure tweets :  {'neg': 0.0, 'neu': 1.0, 'pos': 0.0, 'compound': 0.0}
# Azure tweets :  {'neg': 0.0, 'neu': 0.918, 'pos': 0.082, 'compound': 0.1779}
# Azure tweets :  {'neg': 0.0, 'neu': 1.0, 'pos': 0.0, 'compound': 0.0}
# Azure tweets :  {'neg': 0.0, 'neu': 0.741, 'pos': 0.259, 'compound': 0.4939}
# Azure tweets :  {'neg': 0.0, 'neu': 1.0, 'pos': 0.0, 'compound': 0.0}
# Azure tweets :  {'neg': 0.0, 'neu': 1.0, 'pos': 0.0, 'compound': 0.0}
# Azure tweets :  {'neg': 0.0, 'neu': 0.829, 'pos': 0.171, 'compound': 0.4767}
#
# salesforce tweets :  {'neg': 0.0, 'neu': 0.862, 'pos': 0.138, 'compound': 0.4939}
# salesforce tweets :  {'neg': 0.0, 'neu': 1.0, 'pos': 0.0, 'compound': 0.0}
# salesforce tweets :  {'neg': 0.0, 'neu': 1.0, 'pos': 0.0, 'compound': 0.0}
# salesforce tweets :  {'neg': 0.0, 'neu': 0.779, 'pos': 0.221, 'compound': 0.4003}
# salesforce tweets :  {'neg': 0.0, 'neu': 1.0, 'pos': 0.0, 'compound': 0.0}
# salesforce tweets :  {'neg': 0.0, 'neu': 0.697, 'pos': 0.303, 'compound': 0.8655}
# salesforce tweets :  {'neg': 0.0, 'neu': 0.779, 'pos': 0.221, 'compound': 0.4003}
# salesforce tweets :  {'neg': 0.0, 'neu': 0.856, 'pos': 0.144, 'compound': 0.5719}
# salesforce tweets :  {'neg': 0.0, 'neu': 0.66, 'pos': 0.34, 'compound': 0.7707}
# salesforce tweets :  {'neg': 0.0, 'neu': 0.805, 'pos': 0.195, 'compound': 0.5242}
# salesforce tweets :  {'neg': 0.0, 'neu': 0.816, 'pos': 0.184, 'compound': 0.5242}
# salesforce tweets :  {'neg': 0.0, 'neu': 1.0, 'pos': 0.0, 'compound': 0.0}
# salesforce tweets :  {'neg': 0.0, 'neu': 1.0, 'pos': 0.0, 'compound': 0.0}
# salesforce tweets :  {'neg': 0.316, 'neu': 0.684, 'pos': 0.0, 'compound': -0.5719}
# salesforce tweets :  {'neg': 0.0, 'neu': 0.885, 'pos': 0.115, 'compound': 0.3818}
# salesforce tweets :  {'neg': 0.0, 'neu': 1.0, 'pos': 0.0, 'compound': 0.0}
# salesforce tweets :  {'neg': 0.0, 'neu': 1.0, 'pos': 0.0, 'compound': 0.0}
# salesforce tweets :  {'neg': 0.0, 'neu': 0.785, 'pos': 0.215, 'compound': 0.508}
# salesforce tweets :  {'neg': 0.0, 'neu': 0.746, 'pos': 0.254, 'compound': 0.5267}
# salesforce tweets :  {'neg': 0.0, 'neu': 0.846, 'pos': 0.154, 'compound': 0.4767}
# salesforce tweets :  {'neg': 0.0, 'neu': 0.829, 'pos': 0.171, 'compound': 0.4767}
# salesforce tweets :  {'neg': 0.11, 'neu': 0.818, 'pos': 0.071, 'compound': -0.2406}
# salesforce tweets :  {'neg': 0.0, 'neu': 1.0, 'pos': 0.0, 'compound': 0.0}
# salesforce tweets :  {'neg': 0.0, 'neu': 1.0, 'pos': 0.0, 'compound': 0.0}
# salesforce tweets :  {'neg': 0.08, 'neu': 0.873, 'pos': 0.047, 'compound': -0.2263}
# salesforce tweets :  {'neg': 0.0, 'neu': 1.0, 'pos': 0.0, 'compound': 0.0}
# salesforce tweets :  {'neg': 0.0, 'neu': 1.0, 'pos': 0.0, 'compound': 0.0}
# salesforce tweets :  {'neg': 0.0, 'neu': 0.884, 'pos': 0.116, 'compound': 0.2714}
# salesforce tweets :  {'neg': 0.0, 'neu': 0.722, 'pos': 0.278, 'compound': 0.6597}
# salesforce tweets :  {'neg': 0.0, 'neu': 0.726, 'pos': 0.274, 'compound': 0.5994}
# salesforce tweets :  {'neg': 0.0, 'neu': 0.76, 'pos': 0.24, 'compound': 0.6249}
# salesforce tweets :  {'neg': 0.0, 'neu': 1.0, 'pos': 0.0, 'compound': 0.0}
# salesforce tweets :  {'neg': 0.0, 'neu': 0.76, 'pos': 0.24, 'compound': 0.69}
# salesforce tweets :  {'neg': 0.0, 'neu': 0.738, 'pos': 0.262, 'compound': 0.69}
# salesforce tweets :  {'neg': 0.0, 'neu': 0.891, 'pos': 0.109, 'compound': 0.296}
# salesforce tweets :  {'neg': 0.0, 'neu': 0.848, 'pos': 0.152, 'compound': 0.5267}
# salesforce tweets :  {'neg': 0.0, 'neu': 1.0, 'pos': 0.0, 'compound': 0.0}
# salesforce tweets :  {'neg': 0.0, 'neu': 1.0, 'pos': 0.0, 'compound': 0.0}
# salesforce tweets :  {'neg': 0.0, 'neu': 1.0, 'pos': 0.0, 'compound': 0.0}
# salesforce tweets :  {'neg': 0.0, 'neu': 0.843, 'pos': 0.157, 'compound': 0.4215}
# salesforce tweets :  {'neg': 0.0, 'neu': 0.88, 'pos': 0.12, 'compound': 0.3818}
# salesforce tweets :  {'neg': 0.0, 'neu': 0.825, 'pos': 0.175, 'compound': 0.5242}
# salesforce tweets :  {'neg': 0.0, 'neu': 0.688, 'pos': 0.312, 'compound': 0.7096}
# salesforce tweets :  {'neg': 0.0, 'neu': 0.801, 'pos': 0.199, 'compound': 0.4995}
# salesforce tweets :  {'neg': 0.0, 'neu': 0.805, 'pos': 0.195, 'compound': 0.5242}
# salesforce tweets :  {'neg': 0.0, 'neu': 0.805, 'pos': 0.195, 'compound': 0.5242}
# salesforce tweets :  {'neg': 0.0, 'neu': 0.762, 'pos': 0.238, 'compound': 0.6892}
# salesforce tweets :  {'neg': 0.09, 'neu': 0.857, 'pos': 0.053, 'compound': -0.2263}
# salesforce tweets :  {'neg': 0.061, 'neu': 0.609, 'pos': 0.33, 'compound': 0.8829}
# salesforce tweets :  {'neg': 0.0, 'neu': 0.838, 'pos': 0.162, 'compound': 0.5093}
# salesforce tweets :  {'neg': 0.0, 'neu': 0.68, 'pos': 0.32, 'compound': 0.8555}
# salesforce tweets :  {'neg': 0.0, 'neu': 0.936, 'pos': 0.064, 'compound': 0.0772}
# salesforce tweets :  {'neg': 0.12, 'neu': 0.802, 'pos': 0.078, 'compound': -0.2406}
# salesforce tweets :  {'neg': 0.0, 'neu': 0.942, 'pos': 0.058, 'compound': 0.0772}
# salesforce tweets :  {'neg': 0.0, 'neu': 0.807, 'pos': 0.193, 'compound': 0.4767}
# salesforce tweets :  {'neg': 0.0, 'neu': 1.0, 'pos': 0.0, 'compound': 0.0}
# salesforce tweets :  {'neg': 0.065, 'neu': 0.585, 'pos': 0.35, 'compound': 0.8829}
# salesforce tweets :  {'neg': 0.0, 'neu': 1.0, 'pos': 0.0, 'compound': 0.0}
# salesforce tweets :  {'neg': 0.0, 'neu': 0.885, 'pos': 0.115, 'compound': 0.3818}
# salesforce tweets :  {'neg': 0.0, 'neu': 1.0, 'pos': 0.0, 'compound': 0.0}
# salesforce tweets :  {'neg': 0.0, 'neu': 0.753, 'pos': 0.247, 'compound': 0.5574}
# salesforce tweets :  {'neg': 0.0, 'neu': 1.0, 'pos': 0.0, 'compound': 0.0}
# salesforce tweets :  {'neg': 0.0, 'neu': 0.874, 'pos': 0.126, 'compound': 0.3818}
# salesforce tweets :  {'neg': 0.0, 'neu': 1.0, 'pos': 0.0, 'compound': 0.0}
# salesforce tweets :  {'neg': 0.0, 'neu': 0.78, 'pos': 0.22, 'compound': 0.4767}
# salesforce tweets :  {'neg': 0.0, 'neu': 0.704, 'pos': 0.296, 'compound': 0.7096}
# salesforce tweets :  {'neg': 0.0, 'neu': 0.867, 'pos': 0.133, 'compound': 0.3818}
# salesforce tweets :  {'neg': 0.0, 'neu': 0.789, 'pos': 0.211, 'compound': 0.4588}
# salesforce tweets :  {'neg': 0.0, 'neu': 1.0, 'pos': 0.0, 'compound': 0.0}
# salesforce tweets :  {'neg': 0.0, 'neu': 0.746, 'pos': 0.254, 'compound': 0.7983}
# salesforce tweets :  {'neg': 0.0, 'neu': 0.746, 'pos': 0.254, 'compound': 0.7983}
# salesforce tweets :  {'neg': 0.0, 'neu': 0.867, 'pos': 0.133, 'compound': 0.3818}
# salesforce tweets :  {'neg': 0.0, 'neu': 0.793, 'pos': 0.207, 'compound': 0.34}
# salesforce tweets :  {'neg': 0.0, 'neu': 0.923, 'pos': 0.077, 'compound': 0.1511}
# salesforce tweets :  {'neg': 0.0, 'neu': 0.603, 'pos': 0.397, 'compound': 0.9215}
# salesforce tweets :  {'neg': 0.082, 'neu': 0.773, 'pos': 0.146, 'compound': 0.3595}
# salesforce tweets :  {'neg': 0.0, 'neu': 0.914, 'pos': 0.086, 'compound': 0.128}
# salesforce tweets :  {'neg': 0.0, 'neu': 0.856, 'pos': 0.144, 'compound': 0.4019}
# salesforce tweets :  {'neg': 0.0, 'neu': 1.0, 'pos': 0.0, 'compound': 0.0}
# salesforce tweets :  {'neg': 0.0, 'neu': 0.872, 'pos': 0.128, 'compound': 0.296}
# salesforce tweets :  {'neg': 0.0, 'neu': 1.0, 'pos': 0.0, 'compound': 0.0}
# salesforce tweets :  {'neg': 0.0, 'neu': 0.816, 'pos': 0.184, 'compound': 0.6458}
# salesforce tweets :  {'neg': 0.0, 'neu': 0.719, 'pos': 0.281, 'compound': 0.6892}
# salesforce tweets :  {'neg': 0.0, 'neu': 0.641, 'pos': 0.359, 'compound': 0.8065}
# salesforce tweets :  {'neg': 0.0, 'neu': 0.753, 'pos': 0.247, 'compound': 0.5574}
# salesforce tweets :  {'neg': 0.0, 'neu': 0.78, 'pos': 0.22, 'compound': 0.5242}
# salesforce tweets :  {'neg': 0.274, 'neu': 0.541, 'pos': 0.185, 'compound': -0.2462}
# salesforce tweets :  {'neg': 0.0, 'neu': 0.503, 'pos': 0.497, 'compound': 0.8715}
# salesforce tweets :  {'neg': 0.0, 'neu': 1.0, 'pos': 0.0, 'compound': 0.0}
# salesforce tweets :  {'neg': 0.0, 'neu': 1.0, 'pos': 0.0, 'compound': 0.0}
# salesforce tweets :  {'neg': 0.0, 'neu': 1.0, 'pos': 0.0, 'compound': 0.0}
# salesforce tweets :  {'neg': 0.0, 'neu': 1.0, 'pos': 0.0, 'compound': 0.0}
# salesforce tweets :  {'neg': 0.0, 'neu': 0.625, 'pos': 0.375, 'compound': 0.6369}
# salesforce tweets :  {'neg': 0.0, 'neu': 0.798, 'pos': 0.202, 'compound': 0.4201}
# salesforce tweets :  {'neg': 0.0, 'neu': 1.0, 'pos': 0.0, 'compound': 0.0}
# salesforce tweets :  {'neg': 0.0, 'neu': 1.0, 'pos': 0.0, 'compound': 0.0}
# salesforce tweets :  {'neg': 0.0, 'neu': 0.909, 'pos': 0.091, 'compound': 0.128}
# salesforce tweets :  {'neg': 0.0, 'neu': 0.753, 'pos': 0.247, 'compound': 0.5574}
# salesforce tweets :  {'neg': 0.0, 'neu': 0.838, 'pos': 0.162, 'compound': 0.4019}
# salesforce tweets :  {'neg': 0.0, 'neu': 0.855, 'pos': 0.145, 'compound': 0.296}
#
# AWS tweets :  {'neg': 0.0, 'neu': 0.839, 'pos': 0.161, 'compound': 0.3612}
# AWS tweets :  {'neg': 0.0, 'neu': 1.0, 'pos': 0.0, 'compound': 0.0}
# AWS tweets :  {'neg': 0.0, 'neu': 0.909, 'pos': 0.091, 'compound': 0.2732}
# AWS tweets :  {'neg': 0.0, 'neu': 0.792, 'pos': 0.208, 'compound': 0.6369}
# AWS tweets :  {'neg': 0.0, 'neu': 1.0, 'pos': 0.0, 'compound': 0.0}
# AWS tweets :  {'neg': 0.0, 'neu': 1.0, 'pos': 0.0, 'compound': 0.0}
# AWS tweets :  {'neg': 0.0, 'neu': 0.734, 'pos': 0.266, 'compound': 0.6988}
# AWS tweets :  {'neg': 0.0, 'neu': 1.0, 'pos': 0.0, 'compound': 0.0}
# AWS tweets :  {'neg': 0.202, 'neu': 0.798, 'pos': 0.0, 'compound': -0.5859}
# AWS tweets :  {'neg': 0.0, 'neu': 0.904, 'pos': 0.096, 'compound': 0.2023}
# AWS tweets :  {'neg': 0.0, 'neu': 1.0, 'pos': 0.0, 'compound': 0.0}
# AWS tweets :  {'neg': 0.0, 'neu': 1.0, 'pos': 0.0, 'compound': 0.0}
# AWS tweets :  {'neg': 0.0, 'neu': 0.864, 'pos': 0.136, 'compound': 0.296}
# AWS tweets :  {'neg': 0.0, 'neu': 0.881, 'pos': 0.119, 'compound': 0.3182}
# AWS tweets :  {'neg': 0.0, 'neu': 0.874, 'pos': 0.126, 'compound': 0.3182}
# AWS tweets :  {'neg': 0.0, 'neu': 0.874, 'pos': 0.126, 'compound': 0.3182}
# AWS tweets :  {'neg': 0.0, 'neu': 1.0, 'pos': 0.0, 'compound': 0.0}
# AWS tweets :  {'neg': 0.0, 'neu': 0.733, 'pos': 0.267, 'compound': 0.6249}
# AWS tweets :  {'neg': 0.0, 'neu': 0.922, 'pos': 0.078, 'compound': 0.1779}
# AWS tweets :  {'neg': 0.136, 'neu': 0.657, 'pos': 0.207, 'compound': 0.1027}
# AWS tweets :  {'neg': 0.0, 'neu': 0.731, 'pos': 0.269, 'compound': 0.7096}
# AWS tweets :  {'neg': 0.0, 'neu': 1.0, 'pos': 0.0, 'compound': 0.0}
# AWS tweets :  {'neg': 0.0, 'neu': 0.899, 'pos': 0.101, 'compound': 0.2023}
# AWS tweets :  {'neg': 0.0, 'neu': 1.0, 'pos': 0.0, 'compound': 0.0}
# AWS tweets :  {'neg': 0.0, 'neu': 1.0, 'pos': 0.0, 'compound': 0.0}
# AWS tweets :  {'neg': 0.0, 'neu': 1.0, 'pos': 0.0, 'compound': 0.0}
# AWS tweets :  {'neg': 0.0, 'neu': 0.827, 'pos': 0.173, 'compound': 0.4926}
# AWS tweets :  {'neg': 0.0, 'neu': 0.86, 'pos': 0.14, 'compound': 0.4767}
# AWS tweets :  {'neg': 0.0, 'neu': 1.0, 'pos': 0.0, 'compound': 0.0}
# AWS tweets :  {'neg': 0.0, 'neu': 0.922, 'pos': 0.078, 'compound': 0.1779}
# AWS tweets :  {'neg': 0.0, 'neu': 0.811, 'pos': 0.189, 'compound': 0.4926}
# AWS tweets :  {'neg': 0.0, 'neu': 1.0, 'pos': 0.0, 'compound': 0.0}
# AWS tweets :  {'neg': 0.286, 'neu': 0.714, 'pos': 0.0, 'compound': -0.34}
# AWS tweets :  {'neg': 0.0, 'neu': 0.682, 'pos': 0.318, 'compound': 0.8126}
# AWS tweets :  {'neg': 0.0, 'neu': 0.781, 'pos': 0.219, 'compound': 0.4939}
# AWS tweets :  {'neg': 0.0, 'neu': 0.73, 'pos': 0.27, 'compound': 0.6025}
# AWS tweets :  {'neg': 0.0, 'neu': 1.0, 'pos': 0.0, 'compound': 0.0}
# AWS tweets :  {'neg': 0.0, 'neu': 0.82, 'pos': 0.18, 'compound': 0.5106}
# AWS tweets :  {'neg': 0.286, 'neu': 0.714, 'pos': 0.0, 'compound': -0.34}
# AWS tweets :  {'neg': 0.0, 'neu': 0.741, 'pos': 0.259, 'compound': 0.4939}
# AWS tweets :  {'neg': 0.0, 'neu': 0.825, 'pos': 0.175, 'compound': 0.1779}
# AWS tweets :  {'neg': 0.0, 'neu': 0.755, 'pos': 0.245, 'compound': 0.3818}
# AWS tweets :  {'neg': 0.091, 'neu': 0.909, 'pos': 0.0, 'compound': -0.2263}
# AWS tweets :  {'neg': 0.0, 'neu': 1.0, 'pos': 0.0, 'compound': 0.0}
# AWS tweets :  {'neg': 0.0, 'neu': 1.0, 'pos': 0.0, 'compound': 0.0}
# AWS tweets :  {'neg': 0.0, 'neu': 0.794, 'pos': 0.206, 'compound': 0.6369}
# AWS tweets :  {'neg': 0.0, 'neu': 0.798, 'pos': 0.202, 'compound': 0.5106}
# AWS tweets :  {'neg': 0.0, 'neu': 1.0, 'pos': 0.0, 'compound': 0.0}
# AWS tweets :  {'neg': 0.0, 'neu': 1.0, 'pos': 0.0, 'compound': 0.0}
# AWS tweets :  {'neg': 0.0, 'neu': 0.798, 'pos': 0.202, 'compound': 0.5106}
# AWS tweets :  {'neg': 0.508, 'neu': 0.492, 'pos': 0.0, 'compound': -0.4767}
# AWS tweets :  {'neg': 0.0, 'neu': 0.892, 'pos': 0.108, 'compound': 0.1779}
# AWS tweets :  {'neg': 0.0, 'neu': 0.841, 'pos': 0.159, 'compound': 0.5562}
# AWS tweets :  {'neg': 0.0, 'neu': 0.68, 'pos': 0.32, 'compound': 0.7906}
# AWS tweets :  {'neg': 0.0, 'neu': 0.841, 'pos': 0.159, 'compound': 0.5562}
# AWS tweets :  {'neg': 0.0, 'neu': 0.776, 'pos': 0.224, 'compound': 0.6369}
# AWS tweets :  {'neg': 0.0, 'neu': 0.889, 'pos': 0.111, 'compound': 0.2481}
# AWS tweets :  {'neg': 0.0, 'neu': 1.0, 'pos': 0.0, 'compound': 0.0}
# AWS tweets :  {'neg': 0.0, 'neu': 0.856, 'pos': 0.144, 'compound': 0.4019}
# AWS tweets :  {'neg': 0.0, 'neu': 0.601, 'pos': 0.399, 'compound': 0.8519}
# AWS tweets :  {'neg': 0.0, 'neu': 0.925, 'pos': 0.075, 'compound': 0.1779}
# AWS tweets :  {'neg': 0.0, 'neu': 0.841, 'pos': 0.159, 'compound': 0.5267}
# AWS tweets :  {'neg': 0.0, 'neu': 0.841, 'pos': 0.159, 'compound': 0.5267}
# AWS tweets :  {'neg': 0.0, 'neu': 0.817, 'pos': 0.183, 'compound': 0.5562}
# AWS tweets :  {'neg': 0.0, 'neu': 0.841, 'pos': 0.159, 'compound': 0.5267}
# AWS tweets :  {'neg': 0.106, 'neu': 0.894, 'pos': 0.0, 'compound': -0.2263}
# AWS tweets :  {'neg': 0.0, 'neu': 0.82, 'pos': 0.18, 'compound': 0.5106}
# AWS tweets :  {'neg': 0.0, 'neu': 0.891, 'pos': 0.109, 'compound': 0.296}
# AWS tweets :  {'neg': 0.0, 'neu': 0.784, 'pos': 0.216, 'compound': 0.5106}
# AWS tweets :  {'neg': 0.0, 'neu': 0.617, 'pos': 0.383, 'compound': 0.8271}
# AWS tweets :  {'neg': 0.106, 'neu': 0.894, 'pos': 0.0, 'compound': -0.2263}
# AWS tweets :  {'neg': 0.0, 'neu': 1.0, 'pos': 0.0, 'compound': 0.0}
# AWS tweets :  {'neg': 0.0, 'neu': 1.0, 'pos': 0.0, 'compound': 0.0}
# AWS tweets :  {'neg': 0.0, 'neu': 0.838, 'pos': 0.162, 'compound': 0.4404}
# AWS tweets :  {'neg': 0.0, 'neu': 0.773, 'pos': 0.227, 'compound': 0.6124}
# AWS tweets :  {'neg': 0.284, 'neu': 0.639, 'pos': 0.077, 'compound': -0.5513}
# AWS tweets :  {'neg': 0.0, 'neu': 0.88, 'pos': 0.12, 'compound': 0.3818}
# AWS tweets :  {'neg': 0.0, 'neu': 0.893, 'pos': 0.107, 'compound': 0.34}
# AWS tweets :  {'neg': 0.0, 'neu': 1.0, 'pos': 0.0, 'compound': 0.0}
# AWS tweets :  {'neg': 0.0, 'neu': 0.87, 'pos': 0.13, 'compound': 0.4019}
# AWS tweets :  {'neg': 0.0, 'neu': 1.0, 'pos': 0.0, 'compound': 0.0}
# AWS tweets :  {'neg': 0.0, 'neu': 0.898, 'pos': 0.102, 'compound': 0.3612}
# AWS tweets :  {'neg': 0.0, 'neu': 0.632, 'pos': 0.368, 'compound': 0.8519}
# AWS tweets :  {'neg': 0.0, 'neu': 1.0, 'pos': 0.0, 'compound': 0.0}
# AWS tweets :  {'neg': 0.0, 'neu': 1.0, 'pos': 0.0, 'compound': 0.0}
# AWS tweets :  {'neg': 0.0, 'neu': 0.854, 'pos': 0.146, 'compound': 0.34}
# AWS tweets :  {'neg': 0.0, 'neu': 0.632, 'pos': 0.368, 'compound': 0.8519}
# AWS tweets :  {'neg': 0.0, 'neu': 1.0, 'pos': 0.0, 'compound': 0.0}
# AWS tweets :  {'neg': 0.0, 'neu': 0.864, 'pos': 0.136, 'compound': 0.4588}
# AWS tweets :  {'neg': 0.0, 'neu': 1.0, 'pos': 0.0, 'compound': 0.0}
# AWS tweets :  {'neg': 0.0, 'neu': 1.0, 'pos': 0.0, 'compound': 0.0}
# AWS tweets :  {'neg': 0.0, 'neu': 0.876, 'pos': 0.124, 'compound': 0.1779}
# AWS tweets :  {'neg': 0.0, 'neu': 1.0, 'pos': 0.0, 'compound': 0.0}
# AWS tweets :  {'neg': 0.0, 'neu': 1.0, 'pos': 0.0, 'compound': 0.0}
# AWS tweets :  {'neg': 0.0, 'neu': 1.0, 'pos': 0.0, 'compound': 0.0}
# AWS tweets :  {'neg': 0.0, 'neu': 1.0, 'pos': 0.0, 'compound': 0.0}
# AWS tweets :  {'neg': 0.0, 'neu': 0.826, 'pos': 0.174, 'compound': 0.4215}
# AWS tweets :  {'neg': 0.0, 'neu': 0.925, 'pos': 0.075, 'compound': 0.1779}
# AWS tweets :  {'neg': 0.0, 'neu': 0.734, 'pos': 0.266, 'compound': 0.8225}
# AWS tweets :  {'neg': 0.091, 'neu': 0.909, 'pos': 0.0, 'compound': -0.2263}

# %%
from mpl_toolkits.mplot3d import Axes3D
import matplotlib.pyplot as plt


#build our figure
fig = plt.figure()
#build axes
ax=fig.add_subplot(111,projection='3d')

sentiments = [get_sentiments(tweet.text) for tweet in Azure]


xs=[]
for sent in sentiments:
    xs.append(sent['neg'])
    
ys=[sent['neu'] for sent in sentiments]

zs = list(map(lambda x:x['pos'],sentiments))

ax.scatter(xs,ys,zs)

from nltk_helper import split_sentiments

vX,vY,vZ = split_sentiments([get_sentiments(tweet.text) for tweet in tweepy.Cursor(api.search,q="#salesforce",
                           lang="en").items(100)])
  
ax.scatter(vX,vY,vZ, color='r',marker='*')

ax.set_xlabel('Negative')
ax.set_ylabel('neutral')
ax.set_zlabel('postive')




zX,zY,zZ = split_sentiments([get_sentiments(tweet.text) for tweet in tweepy.Cursor(api.search,q="#AWS",
                           lang="en").items(100)])
ax.scatter(zX,zY,zZ, color='g',marker='d')
ax.scatter(zX,zY,zZ)

ax.scatter(xs,ys,zs)
ax.set_xlabel('Negative')
ax.set_ylabel('neutral')
ax.set_zlabel('postive')

plt.show()

# %%
from nltk.sentiment.vader import SentimentIntensityAnalyzer
analyzer = SentimentIntensityAnalyzer()

positive1 = []
negative1 = []
neutral1 = []
for tweet in tweepy.Cursor(api.search,q="#Azure",
                           lang="en").items(100):   
    if(analyzer.polarity_scores(tweet.text)['compound']) >=0.5:        
        positive1.append(tweet.text)
    elif(analyzer.polarity_scores(tweet.text)['compound']) <= -0.5:        
        negative1.append(tweet.text)
    else:
        neutral1.append(tweet.text) 
        

        
positive2 = []
negative2 = []
neutral2 = []       
for tweet in tweepy.Cursor(api.search,q="#salesforce",
                           lang="en").items(100):   
    if(analyzer.polarity_scores(tweet.text)['compound']) >=0.5:        
        positive2.append(tweet.text)
    elif(analyzer.polarity_scores(tweet.text)['compound']) <= -0.5:        
        negative2.append(tweet.text)
    else:
        neutral2.append(tweet.text)  

positive3 = []
negative3 = []
neutral3 = []
for tweet in tweepy.Cursor(api.search,q="#AWS",
                           lang="en").items(100):   
    if(analyzer.polarity_scores(tweet.text)['compound']) >=0.5:        
        positive3.append(tweet.text)
    elif(analyzer.polarity_scores(tweet.text)['compound']) <= -0.5:        
        negative3.append(tweet.text)
    else:
        neutral3.append(tweet.text)           


print()
total1=len(positive1)+len(negative1)+len(neutral1)
per_pos1=len(positive1)/total1*100
per_neg1=len(negative1)/total1*100
per_neu1=len(neutral1)/total1*100

print('percentage of positive tweets for Azure: ',per_pos1)
print('percentageof negative tweets for Azure: ',per_neg1)
print('percentage of neutral tweets for Azure: ',per_neu1)
print('---------------------------------------------')



total2=len(positive2)+len(negative2)+len(neutral2)
per_pos2=len(positive2)/total2*100
per_neg2=len(negative2)/total2*100
per_neu2=len(neutral2)/total2*100

print('percentage of positive tweets for salesforce: ',per_pos2)
print('percentage of negative tweets for salesforce: ',per_neg2)
print('percentage of neutral tweets for salesforce: ',per_neu2)
print('---------------------------------------------')
'''
print(positive2)
print(negative2)
print(neutral2)
'''

total3=len(positive3)+len(negative3)+len(neutral3)
per_pos3=len(positive3)/total3*100
per_neg3=len(negative3)/total3*100
per_neu3=len(neutral3)/total3*100

print('percentage of positive tweets for AWS: ',per_pos3)
print('percentage of negative tweets for AWS : ',per_neg3)
print('percentage of neutral tweets for AWS: ',per_neu3)
'''
print(positive3)
print(negative3)
print(neutral3)
'''
import matplotlib.pyplot as plt
 
# set width of bar
barWidth = 0.1
 
# set height of bar
'''
postiveFinal = [per_pos1,per_pos2,per_pos3]
negativeFinal = [per_neg1, per_neg2, per_neg3]
neutralFinal = [per_neu1, per_neu2, per_neu3]
'''
postiveFinal = [per_pos1,per_neg1,per_neu1]
negativeFinal = [per_pos2, per_neg2, per_neu2]
neutralFinal = [per_pos3, per_neg3, per_neu3]
 


fig = plt.figure()

plt.ylim(0, 100)

n=3

index=np.arange(n)

barwidth=0.25

opacity=0.8

objects=('Postive','Negative','Neutral')

 

rects1 = plt.bar(index, postiveFinal, barwidth,

alpha=opacity,

color='r',

label='Azure')

 

rects2 = plt.bar(index + barwidth, negativeFinal, barwidth,

alpha=opacity,

color='y',

label='salesforce')

 

 

rects3 = plt.bar(index +barwidth+ barwidth, neutralFinal, barwidth,

alpha=opacity,

color='b',

label='AWS')

 

 



plt.xticks(index + barwidth,objects)

plt.ylabel('units in percentage (%)')
plt.xlabel(' POLARITY CLASSIFICATION')           
           

plt.title('Trending Cloud Service Provider')
  

plt.legend()

plt.tight_layout()



 

plt.show()
# Out:
# percentage of positive tweets for Azure:  14.000000000000002
# percentageof negative tweets for Azure:  0.0
# percentage of neutral tweets for Azure:  86.0
# ---------------------------------------------
# percentage of positive tweets for salesforce:  35.0
# percentage of negative tweets for salesforce:  1.0
# percentage of neutral tweets for salesforce:  64.0
# ---------------------------------------------
# percentage of positive tweets for AWS:  26.0
# percentage of negative tweets for AWS :  2.0
# percentage of neutral tweets for AWS:  72.0

# %% [markdown]
# ## Conclusion :
#
# As we are getting the data from the twitter the trends may change from time to time . This tool will be very useful whenever there is an update to any cloud service provider among these three cloud service providers. From the results of these tweets we can understand how efficiently the update is good and necessary. For the particular momment all the cloud service providers are performing consistently  with more percentage of positive tweets for salesforce and more neutral tweet percentage for the Azure , AWS and salesforce cloud service providers has a little negative tweets percentage .
